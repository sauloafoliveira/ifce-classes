# %% [markdown]
# <a href="https://colab.research.google.com/github/sauloafoliveira/ifce-classes/blob/master/logpro/LOGPRO_2020_AULA_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **VAMOS COMEÇAR COM OS TUTORIAIS**
#
#
#
# *   A partir de agora, a gente vai usar o colab 100%!
#
# *   Isso quer dizer que vocês vão receber listas de atividades como essa para completar parte das notas de vocês.
#
# *   Para vocês responderem este notebook, vocês vão precisar criar uma cópia dele no Google Drive de vocês. Basta ir no Menu **File** ali em cima e escolher a opção **Save a copy in Drive**.
#
#
# ![Captura de Tela 2020-09-26 às 22.09.13.png](data:image/png;base64,...)
#
#
#
# *   Para entregar, basta ir na opção **Share** ali na parte superior dirieta e digitar meu email: saulo.oliveira@ifce.edu.br.
#
# ![Captura de Tela 2020-09-26 às 22.10.13.png](data:image/png;base64,...)

# %% [markdown]
# 1.   Escreva um programa que imprime "Instituto Federal do Ceará - Campus Tauá" na Tela.
# 2.   Escreva um programa que lê um número inteiro n e imprime a tabuada deste número na  tela. Por exemplo, para n = 3, a seguinte saída deve ser produzida.
# ```
# 3 x 1 = 3
# 3 x 2 = 6
# ...
# 3 x 10 = 30
# ```
# 3.   Escreva um programa que lê um valor de velocidade em quilômetros por hora e imprima  este valor em metros por segundo.
# ```
# 1 metro por segundo = 3,6 quilometros por hora
# ```
# 4.   Escreva um programa que lê a base e a altura de um triângulo e imprime a área deste  triângulo.
#
# 5.   Escreva um programa que lê o raio de uma circunferência e imprime sua área.
#
# 6.   Faça um programa que peça para o usuário digitar 4 valores inteiros, coloque estes valores nas variáveis a, b, c, d e imprima na tela o resultado da seguinte expressão:
# ```
# (a + b + c) x d
# ```
#
# 7.    Faça um programa que leia pelo teclado um valor, em reais, converta e imprima o mesmo num valor em dólares.
# ```
# 1 Dólar americano igual a 5,56 Real brasileiro
# ```
#
# 8.     Faça um programa que imprimao produto dos valores 30 e 27.
#
# 9.     Faça um programa que imprima a média aritmética entre os números 5, 8, 12.
#
# 10.    Faça um programa que leia um número inteiro e imprima o seu antecessor e o seu sucessor.

# %%
# Questão 1
print('Instituto Federal do Ceará - Campus Tauá')

# %%
# Questão 2

# %%
# Questão 3

# %%
# Questão 4

# %%
# Questão 5

# %%
# Questão 6

# %%
# Questão 7

# %%
# Questão 8

# %%
# Questão 9

# %%
# Questão 10
